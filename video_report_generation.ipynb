# %% [markdown]
# # Download YouTube Videos as Audio

# %%
import subprocess

# Path to the youtube-dl executable, run `which youtube-dl` to find
youtube_dl_path = "/home/master/.local/bin/yt-dlp"

output_directory = "0_audio/"

# Your list of video URLs
url_list = ["https://www.youtube.com/watch?v=H1cezQRTMq0",
            "https://www.youtube.com/watch?v=I8CST9vXrm4",
           "https://www.youtube.com/watch?v=I28PKy4AIGI",
           "https://www.youtube.com/watch?v=zoE3DqglcgM",
           "https://www.youtube.com/watch?v=bEovhfxJsM4",
           "https://www.youtube.com/watch?v=_5ocRWk9GLc",
           "https://www.youtube.com/watch?v=9lBbqH_1KS4",
           "https://www.youtube.com/watch?v=AcsEAukECRk",
           "https://www.youtube.com/watch?v=4riGbukyZjg"]

for video_url in url_list:
    # Use subprocess to run youtube-dl command
    command = f"{youtube_dl_path} -f 'bestaudio[ext=m4a]' -o '{output_directory}%(title)s.%(ext)s' {video_url}"
    subprocess.run(command, shell=True)
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=H1cezQRTMq0
# [youtube] H1cezQRTMq0: Downloading webpage
# [youtube] H1cezQRTMq0: Downloading ios player API JSON
# [youtube] H1cezQRTMq0: Downloading android player API JSON
# [youtube] H1cezQRTMq0: Downloading m3u8 information
# [info] H1cezQRTMq0: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Emeritus Lecture—Valedictory： Who Am I？ (Martin Tompa).m4a
# [download] 100% of   56.23MiB in 00:00:07 at 7.39MiB/s
# [FixupM4a] Correcting container of "0_audio/Emeritus Lecture—Valedictory： Who Am I？ (Martin Tompa).m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I8CST9vXrm4
# [youtube] I8CST9vXrm4: Downloading webpage
# [youtube] I8CST9vXrm4: Downloading ios player API JSON
# [youtube] I8CST9vXrm4: Downloading android player API JSON
# [youtube] I8CST9vXrm4: Downloading player 42a553e1
# [youtube] I8CST9vXrm4: Downloading m3u8 information
# [info] I8CST9vXrm4: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Allen School Colloquium： MISL Research Lab.m4a
# [download] 100% of   54.77MiB in 00:00:08 at 6.83MiB/s
# [FixupM4a] Correcting container of "0_audio/Allen School Colloquium： MISL Research Lab.m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=I28PKy4AIGI
# [youtube] I28PKy4AIGI: Downloading webpage
# [youtube] I28PKy4AIGI: Downloading ios player API JSON
# [youtube] I28PKy4AIGI: Downloading android player API JSON
# [youtube] I28PKy4AIGI: Downloading m3u8 information
# [info] I28PKy4AIGI: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Language AI for RNA Virus and RNA Vaccine： Liang Huang (Oregon State University ｜ Coderna.ai).m4a
# [download] 100% of   52.69MiB in 00:00:05 at 10.46MiB/s
# [FixupM4a] Correcting container of "0_audio/Language AI for RNA Virus and RNA Vaccine： Liang Huang (Oregon State University ｜ Coderna.ai).m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zoE3DqglcgM
# [youtube] zoE3DqglcgM: Downloading webpage
# [youtube] zoE3DqglcgM: Downloading ios player API JSON
# [youtube] zoE3DqglcgM: Downloading android player API JSON
# [youtube] zoE3DqglcgM: Downloading m3u8 information
# [info] zoE3DqglcgM: Downloading 1 format(s): 140
# [download] Destination: 0_audio/On Making Mathematic Proof a Business： Byron Cook.m4a
# [download] 100% of   66.06MiB in 00:00:11 at 5.69MiB/s
# [FixupM4a] Correcting container of "0_audio/On Making Mathematic Proof a Business： Byron Cook.m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bEovhfxJsM4
# [youtube] bEovhfxJsM4: Downloading webpage
# [youtube] bEovhfxJsM4: Downloading ios player API JSON
# [youtube] bEovhfxJsM4: Downloading android player API JSON
# [youtube] bEovhfxJsM4: Downloading m3u8 information
# [info] bEovhfxJsM4: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Allen School Distinguished Lecture： Peter Lee (Microsoft Research & Incubations).m4a
# [download] 100% of   64.60MiB in 00:00:10 at 6.14MiB/s
# [FixupM4a] Correcting container of "0_audio/Allen School Distinguished Lecture： Peter Lee (Microsoft Research & Incubations).m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_5ocRWk9GLc
# [youtube] _5ocRWk9GLc: Downloading webpage
# [youtube] _5ocRWk9GLc: Downloading ios player API JSON
# [youtube] _5ocRWk9GLc: Downloading android player API JSON
# [youtube] _5ocRWk9GLc: Downloading m3u8 information
# [info] _5ocRWk9GLc: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Distinguished Lecture： Telle Whitney (Jan 19, 2023).m4a
# [download] 100% of   53.41MiB in 00:00:10 at 4.91MiB/s
# [FixupM4a] Correcting container of "0_audio/Distinguished Lecture： Telle Whitney (Jan 19, 2023).m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9lBbqH_1KS4
# [youtube] 9lBbqH_1KS4: Downloading webpage
# [youtube] 9lBbqH_1KS4: Downloading ios player API JSON
# [youtube] 9lBbqH_1KS4: Downloading android player API JSON
# [youtube] 9lBbqH_1KS4: Downloading m3u8 information
# [info] 9lBbqH_1KS4: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Distinguished Lecture： Amin Vahdat (Jan 12, 2023).m4a
# [download] 100% of   59.26MiB in 00:00:02 at 27.37MiB/s
# [FixupM4a] Correcting container of "0_audio/Distinguished Lecture： Amin Vahdat (Jan 12, 2023).m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=AcsEAukECRk
# [youtube] AcsEAukECRk: Downloading webpage
# [youtube] AcsEAukECRk: Downloading ios player API JSON
# [youtube] AcsEAukECRk: Downloading android player API JSON
# [youtube] AcsEAukECRk: Downloading m3u8 information
# [info] AcsEAukECRk: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Distinguished Lecture： Jenny Lay-Flurrie (Nov 11, 2022).m4a
# [download] 100% of   49.20MiB in 00:00:10 at 4.81MiB/s
# [FixupM4a] Correcting container of "0_audio/Distinguished Lecture： Jenny Lay-Flurrie (Nov 11, 2022).m4a"
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4riGbukyZjg
# [youtube] 4riGbukyZjg: Downloading webpage
# [youtube] 4riGbukyZjg: Downloading ios player API JSON
# [youtube] 4riGbukyZjg: Downloading android player API JSON
# [youtube] 4riGbukyZjg: Downloading m3u8 information
# [youtube] 4riGbukyZjg: Downloading MPD manifest
# [info] 4riGbukyZjg: Downloading 1 format(s): 140
# [download] Destination: 0_audio/Allen School Distinguished Lecture： David Patterson (UC Berkeley + Google).m4a
# [download] 100% of   57.58MiB in 00:00:05 at 11.27MiB/s
# [FixupM4a] Correcting container of "0_audio/Allen School Distinguished Lecture： David Patterson (UC Berkeley + Google).m4a"

# %% [markdown]
# # Convert Audio to Transcripts

# %%
import os
import subprocess
import whisper

model = whisper.load_model("base")
folder_path = "0_audio/"

for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    try:
        result = model.transcribe(file_path)
    except:
      print(f"{filename} failed to be transcribed.")

    output_filename = "1_transcripts/" + os.path.splitext(filename)[0] + ".txt"
    with open(output_filename, 'w') as file:
      file.write(result['text'])

# %% [markdown]
# # Convert Transcripts to Summaries

# %%
import os
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

tokenizer = AutoTokenizer.from_pretrained("pszemraj/led-large-book-summary")
model = AutoModelForSeq2SeqLM.from_pretrained("pszemraj/led-large-book-summary")
classifier = pipeline("summarization", model=model, tokenizer=tokenizer)

# Directory path containing the files
directory_path = "./1_transcripts/"

# Loop over the files in the directory
for filename in os.listdir(directory_path):
    # Check if the file is a text file
    if filename.endswith(".txt"):
        # Open the file for reading
        with open(os.path.join(directory_path, filename), "r") as input_file:
            # Read the contents of the file
            file_contents = input_file.read()
            
            try:
              processed_contents = classifier(
                file_contents,
                min_length=1000,
                max_length=2048,
                no_repeat_ngram_size=3,
                encoder_no_repeat_ngram_size=3,
                repetition_penalty=3.5,
                num_beams=4,
              )
            except:
              print(f"{filename} failed to be summarized.")
            
            # Create a new file for writing the extracted information
            output_filename = "./2_summaries/" + filename
            with open(output_filename, "w") as output_file:
                # Write the processed contents to the new file
                output_file.write(processed_contents[0]['summary_text'])

# %% [markdown]
# use `min_length` to [control how concise the model output](https://github.com/pszemraj/textsum/wiki/Inference-&-Parameters) is. If you have  a very long video that makes a very long summary, the summary may be too big for the context window of the model that generates reports.

# %% [markdown]
# # Convert Summaries to Reports

# %%
from openai import OpenAI
import os

#openai api key
key="YOUR_KEY_HERE"

client = OpenAI(api_key=key)

# Directory path containing the files
directory_path = "./2_summaries/"

# Loop over the files in the directory
for filename in os.listdir(directory_path):
    # Check if the file is a text file
    if filename.endswith(".txt"):
        # Open the file for reading
        with open(os.path.join(directory_path, filename), "r") as input_file:
            # Read the contents of the file
            file_contents = input_file.read()

    completion = client.chat.completions.create(
      model="gpt-3.5-turbo",
      temperature=0,
      messages=[
        {"role": "system", "content": "Pretend you are a student attending lecture. Please give your impressions of the talk and how you benefited from what you learned, in 200 words or less. You MUST include the speaker's name in your report."},
        {"role": "user", "content": f"{file_contents}"}
      ])
    
    result = completion.choices[0].message.content

    # Create a new file for writing the extracted information
    output_filename = "./3_reports/" + filename
    with open(output_filename, "w") as output_file:
        # Write the processed contents to the new file
        output_file.write(result)
